# %%
import pandas as pd

# %%
df_barrons = pd.read_csv("Barrons-333-High-Freq-Words-With-Meanings.csv")

# %%
df_barrons = df_barrons.dropna()

# %%
df_barrons
# Out:
#                  WORD                                            MEANING
# 0               Abate                              subside , or moderate
# 1            Aberrant                               abnormal, or deviant
# 2            Abeyance                                   suspended action
# 3             Abscond                           depart secretly and hide
# 4          Abstemious          sparing in eating and drinking; temperate
# 5            Admonish                                      warn; reprove
# 6          Adulterate  make impure by adding inferior or tainted subs...
# 7           Aesthetic  artistic; dealing with or capable of appreciat...
# 8           Aggregate                                 gather; accumulate
# 9            Alacrity                     cheerful promptness; eagerness
# 10          Alleviate                                            relieve
# 11         Amalgamate                         combine; unite in one body
# ...
